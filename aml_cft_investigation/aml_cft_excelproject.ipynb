# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Project-Title:-Using-Microsoft-Excel,-Identify-Anti-Money-Laundering-(AML)-and-Combating-Financing-of-Terrorism-(CFT)-Financial-Records-Analysis-Project" data-toc-modified-id="Project-Title:-Using-Microsoft-Excel,-Identify-Anti-Money-Laundering-(AML)-and-Combating-Financing-of-Terrorism-(CFT)-Financial-Records-Analysis-Project-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Project Title: Using Microsoft Excel, Identify Anti-Money Laundering (AML) and Combating Financing of Terrorism (CFT) Financial Records Analysis Project</a></span></li><li><span><a href="#Project-Set-up" data-toc-modified-id="Project-Set-up-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Project Set-up</a></span><ul class="toc-item"><li><span><a href="#Import-Data-in-Excel" data-toc-modified-id="Import-Data-in-Excel-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Import Data in Excel</a></span></li><li><span><a href="#Project-Background" data-toc-modified-id="Project-Background-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Project Background</a></span></li></ul></li><li><span><a href="#Transform-&amp;-Protect-Data" data-toc-modified-id="Transform-&amp;-Protect-Data-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Transform &amp; Protect Data</a></span></li><li><span><a href="#Answers-to-AML/CFT-Questions" data-toc-modified-id="Answers-to-AML/CFT-Questions-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Answers to AML/CFT Questions</a></span><ul class="toc-item"><li><span><a href="#Question-#-1:" data-toc-modified-id="Question-#-1:-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Question # 1:</a></span></li><li><span><a href="#Question-#-2:" data-toc-modified-id="Question-#-2:-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Question # 2:</a></span></li><li><span><a href="#Question-#-3:" data-toc-modified-id="Question-#-3:-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Question # 3:</a></span></li><li><span><a href="#Question-#-4:" data-toc-modified-id="Question-#-4:-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Question # 4:</a></span></li><li><span><a href="#Question-#-5:" data-toc-modified-id="Question-#-5:-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Question # 5:</a></span></li><li><span><a href="#Question-#-6:" data-toc-modified-id="Question-#-6:-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Question # 6:</a></span></li></ul></li><li><span><a href="#Project-Walk-through-Video" data-toc-modified-id="Project-Walk-through-Video-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Project Walk-through Video</a></span></li></ul></div>

# %% [markdown]
# # Project Title: Using Microsoft Excel, Identify Anti-Money Laundering (AML) and Combating Financing of Terrorism (CFT) Financial Records Analysis Project

# %% [markdown]
# # Project Set-up

# %% [markdown]
# ## Import Data in Excel

# %% [markdown]
# The data being utilized for this project is synthetic for the purpose of doing this project. The data is in the excel format so no special preparation is required to import the data.
#
# ![dataimport.png](attachment:dataimport.png)

# %% [markdown]
# ## Project Background

# %% [markdown]
# The data is based on a number of fictitious bank transfers done by a person named Edward of Nigeria who is involved in money laundering activities as per the law authorities. He has been transferring money via a Russian bank and other means for which suspected transaction reports (STR's) are provided and the imported dataset is based on it. The money is being sent to a beneficiary named as Mr. N here.
#
# The goals of this project are to answer the following questions:
#
#     - What is the total inflow to MR N for the period given in the data?
#
#     - How much money was sent to MR N from Edward?
#
#     - Are there other people sending money to MR N and from which Jurisdictions?
#
#     - How many jurisdictions money is being sent from?
#
#     - Which local bank received the most funds on behalf of MR N?
#
#     - What is the location of the banks that are beneficiaries of funds on behalf of MR N?

# %% [markdown]
# # Transform & Protect Data

# %% [markdown]
# This **step is extremely important** as like any other investigation, it is important to ensure that data provided is fully kept in the original form and it is recommended always to work on the data after making a copy. This will provide a baseline point for any future requirements during the investigations.
#
# Here are the main steps:
#
# - Make a duplicate copy of the file
# - Protect the original file and keep it in a secured environment
# - Maintain the chain of custody of evidence
# - For the purpose of this exercise, the original data is saved in the tab as 'originalData' and make antoher tab with the original data and save it as 'workingData'.
# - Make sure to protect the 'originalData' tab spreadsheet with a password so that nobody can change it.

# %% [markdown]
# # Answers to AML/CFT Questions

# %% [markdown]
# ## Question # 1:

# %% [markdown]
# **Question: What is the total inflow to MR N for the period given in the data?**
#
# **Answer:**
# Using Pivot table, I can find the list of all the people who are sending money to Mr N as shown below:
#
# ![aml1a_answer.png](attachment:aml1a_answer.png)

# %% [markdown]
# ## Question # 2:

# %% [markdown]
# **Question: How much money was sent to MR N from Edward?**
#
# **Answer:**
# As money is being sent by Edward, we can use the Pivot table to run a scenario covering who is sending the money and the amount as shown below and this information for money sent by Edward is meant for Mr N:
#
# ![aml1answer.png](attachment:aml1answer.png)

# %% [markdown]
# ## Question # 3:

# %% [markdown]
# **Question: Are there other people sending money to MR N and from which Jurisdictions?**
#
# **Answer:**
# Using Pivot table and pivot chart, I already got the list of all the people who are sending money to Mr N as shown below:
#
# ![aml1a_answer.png](attachment:aml1a_answer.png)

# %% [markdown]
# ## Question # 4:

# %% [markdown]
# **Question: How many jurisdictions money is being sent from?**
#
# **Answer:**
# Using Pivot table, I got the list of jurisdictions as count of originating countries as shown below:
#
# ![aml4.png](attachment:aml4.png)

# %% [markdown]
# ## Question # 5:

# %% [markdown]
# **Question: Which local bank received the most funds on behalf of MR N?**
#
# **Answer:**
# Using Pivot table and pivot chart, I got the list of receiving banks along with number of receiving transactions as shown below:
#
# ![aml5.png](attachment:aml5.png)

# %% [markdown]
# ## Question # 6:

# %% [markdown]
# **Question: What is the location of the banks that are beneficiaries of funds on behalf of MR N?**
#
# **Answer:**
# Using Pivot table and pivot chart, I got the list of receiving bank branches and resuts showing how sum of total transactions as shown below:
#
# ![aml6.png](attachment:aml6.png)

# %% [markdown]
# # Project Walk-through Video

# %% [markdown]
# Please watch the below project video walk-through on YouTube at https://www.youtube.com/watch?v=uwZshHOqU80
#
# ![AMLCFT_Videocover.png](attachment:AMLCFT_Videocover.png)
#
# The above images has been provided for your reference purpose only to ensure you are watching the right video on YouTube!

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Financial-Fraud-Project-Documentation" data-toc-modified-id="Financial-Fraud-Project-Documentation-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Financial Fraud Project Documentation<a id="6_Financial_Fraud_Documentation"></a></a></span><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Introduction<a id="6.1_Introduction"></a></a></span></li><li><span><a href="#Methodology-For-Solution" data-toc-modified-id="Methodology-For-Solution-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Methodology For Solution<a id="6.2_Methodology_Solution"></a></a></span><ul class="toc-item"><li><span><a href="#Data-Science-Methodology" data-toc-modified-id="Data-Science-Methodology-6.2.1"><span class="toc-item-num">6.2.1&nbsp;&nbsp;</span>Data Science Methodology<a id="6.2.1_Data_Science_Methodology"></a></a></span></li><li><span><a href="#Problem-Identification" data-toc-modified-id="Problem-Identification-6.2.2"><span class="toc-item-num">6.2.2&nbsp;&nbsp;</span>Problem Identification<a id="6.2.2_Problem_Identification"></a></a></span></li><li><span><a href="#Data-Wrangling" data-toc-modified-id="Data-Wrangling-6.2.3"><span class="toc-item-num">6.2.3&nbsp;&nbsp;</span>Data Wrangling<a id="6.2.3_Data_Wrangling"></a></a></span></li><li><span><a href="#Exploratory-Data-Analysis" data-toc-modified-id="Exploratory-Data-Analysis-6.2.4"><span class="toc-item-num">6.2.4&nbsp;&nbsp;</span>Exploratory Data Analysis<a id="6.2.4_Exploratory_Data_Analysis"></a></a></span></li><li><span><a href="#Pre-Processing-and-Training-Data-Development" data-toc-modified-id="Pre-Processing-and-Training-Data-Development-6.2.5"><span class="toc-item-num">6.2.5&nbsp;&nbsp;</span>Pre-Processing and Training Data Development<a id="6.2.5_Preprocessing_TrainingData_Development"></a></a></span></li><li><span><a href="#Machine-Learning-Modeling" data-toc-modified-id="Machine-Learning-Modeling-6.2.6"><span class="toc-item-num">6.2.6&nbsp;&nbsp;</span>Machine Learning Modeling<a id="6.2.6_Machine_Learning_Modeling"></a></a></span></li><li><span><a href="#Future-Improvements" data-toc-modified-id="Future-Improvements-6.2.7"><span class="toc-item-num">6.2.7&nbsp;&nbsp;</span>Future Improvements<a id="6.2.7_Future_Improvements"></a></a></span></li><li><span><a href="#Credits" data-toc-modified-id="Credits-6.2.8"><span class="toc-item-num">6.2.8&nbsp;&nbsp;</span>Credits<a id="6.2.8_Credits"></a></a></span></li><li><span><a href="#Jupyter-Notebooks-For-Detailed-Steps" data-toc-modified-id="Jupyter-Notebooks-For-Detailed-Steps-6.2.9"><span class="toc-item-num">6.2.9&nbsp;&nbsp;</span>Jupyter Notebooks For Detailed Steps<a id="6.2.9_Jupyter_Notebooks"></a></a></span></li><li><span><a href="#Presentation-Slides" data-toc-modified-id="Presentation-Slides-6.2.10"><span class="toc-item-num">6.2.10&nbsp;&nbsp;</span>Presentation Slides<a id="6.2.11_Presentation_Slides"></a></a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Financial Fraud Project Documentation<a id='6_Financial_Fraud_Documentation'></a>

# %% [markdown]
# ![intromobilefrauds.png](attachment:intromobilefrauds.png)
# (Image source Credit: http://100.24.114.164/files/pdf/RP151_Fraud_in_Mobile_Financial_Services_JMudiri.pdf)

# %% [markdown]
# ## Introduction<a id='6.1_Introduction'></a>

# %% [markdown]
# As per the <a href="http://documents1.worldbank.org/curated/en/249151504766545101/pdf/119208-BRI-PUBLIC-Brief-Fraud-in-Mobile-Financial-Services-April-2017.pdf" target="_blank">World Bank report</a>, the rise of mobile financial services (MFS) is one of the most important contributors towards the financial inclusion in the emerging markets. While it has facilitated cheap and reliable financial services to formerly unbanked population segment. With the growing use of these services, there is a growth in the financial frauds too.
#
# Financial frauds detection is an important research field and that's why the synethic data based in the aggregate real data was simulated by PaySim. The current dataset is provided by the <a href="https://www.kaggle.com/ntnu-testimon/paysim1" target="_blank">PaySim Data research team at Kaggle</a> that resembles the normal operation of transactions and injects malicious behaviour to later evaluate the performance of fraud detection methods.
#
# Here is the special recognition to the team which provided this data:
#
# ![dataacknowledgement.png](attachment:dataacknowledgement.png)

# %% [markdown]
# ## Methodology For Solution<a id='6.2_Methodology_Solution'></a>

# %% [markdown]
# ### Data Science Methodology<a id='6.2.1_Data_Science_Methodology'></a>

# %% [markdown]
# PaySim simulated mobile money transactions based on a sample of real transactions extracted from one month of financial logs from a mobile money service implemented in an African country. The main focus is to find out the machine learning data science method which can proactively identify the fraud based on the transactions.
#
# To facilitate the the solution for this project, I am using the <b>data science methodology (DSM)</b> for the overall analysis with the steps shown in the below picture:
# ![MLmethodology.jpg](attachment:MLmethodology.jpg)

# %% [markdown]
# ### Problem Identification<a id='6.2.2_Problem_Identification'></a>

# %% [markdown]
# During this phase, the focus was on understanding the background, the data provided and the expectations from the solution. The main focus as identified during the problem identification phase is to come up with a machine learning model which can identify the financial fraud patterns.
#
# ![MLinfograph1.jpg](attachment:MLinfograph1.jpg)
#
# Keeping the above in mind, there is no focus here on mitigation or finding any proactive solutions as a comprehensive mitigation solution can not be generated in the absence of full details of the work flow scenario and other current mitigations in place.
#
# - Find the best machine learning model to identify the financial frauds

# %% [markdown]
# ### Data Wrangling<a id='6.2.3_Data_Wrangling'></a>

# %% [markdown]
# During the data wrangling phase, the data is sourced, loaded and extracted to identify the data structure, data features, missing data, data types, target features, and clean data for the project requirements.
#
# ![MLinfograph2.jpg](attachment:MLinfograph2.jpg)
#
# Here is the summary of the data as shown below:
#
# ![datawrangling.png](attachment:datawrangling.png)
#
# ![arrow.png](attachment:arrow.png)
#
# For the step by step details of the data wrangling phase, please click at the <a href="https://github.com/jayguptacal/BankingAndInvestments/blob/main/FinancialFraudDetection/Financial_Frauds_DataWrangling.ipynb" target="_blank">Data Wrangling Notebook</a>. While opening this link, please open in a separate browser window by right-clicking and then opening it so that this summary notebook remains open. The data sometimes may not load properly, so please reload it until it shows properly.

# %% [markdown]
# ### Exploratory Data Analysis<a id='6.2.4_Exploratory_Data_Analysis'></a>

# %% [markdown]
# The main focus during the EDA phase is on exploring insights from the data.
#
# ![MLinfograph3.jpg](attachment:MLinfograph3.jpg)
#
# Cash out and transfers were two transaction types where the frauds were located. One feature column 'isFlaggedFraud' was dropped as it is not adding any value to the whole analysis. Thereafter the main focus was on the 'isFraud' column as the target feature.
#
# ![fraud-eda.png](attachment:fraud-eda.png)
#
# ![arrow.png](attachment:arrow.png)
# For the step by step details of the EDA phase, please click at the <a href="https://github.com/jayguptacal/BankingAndInvestments/blob/main/FinancialFraudDetection/Financial_Frauds_Exploratory_Data_Analysis.ipynb" target="_blank">Exploratory Data Analysis Notebook</a>. While opening this link, please open in a separate browser window by right-clicking and then opening it so that this summary notebook remains open. The data sometimes may not load properly, so please reload it until it shows properly.

# %% [markdown]
# ### Pre-Processing and Training Data Development<a id='6.2.5_Preprocessing_TrainingData_Development'></a>

# %% [markdown]
# During this phase, data was made ready for the machine learning phase.
#
# ![MLinfograph5.jpg](attachment:MLinfograph5.jpg)
#
# Using feature engineering techniques, new features were created as shown below:
#
# ![newfeatures.png](attachment:newfeatures.png)
#
# Data skewness was confirmed as shown below:
#
# ![dataskewness.png](attachment:dataskewness.png)
#
# Finally to make the data ready for the machine learning modeling, category was converted into the numerical type as shown below:
#
# ![categoryencoding.png](attachment:categoryencoding.png)
#
# ![arrow.png](attachment:arrow.png)
# For the step by step details of the Pre-Processing and Training Data Development phase, please click at the <a href="https://github.com/jayguptacal/BankingAndInvestments/blob/main/FinancialFraudDetection/Financial_Frauds_Preprocessing.ipynb" target="_blank">Pre-Processing Notebook</a>. While opening this link, please open in a separate browser window by right-clicking and then opening it so that this summary notebook remains open. The data sometimes may not load properly, so please reload it until it shows properly.

# %% [markdown]
# ### Machine Learning Modeling<a id='6.2.6_Machine_Learning_Modeling'></a>

# %% [markdown]
# The focus of this notebook is to split the data into X and y variables and then split into training set and testing set.
#
# ![MLinfograph5.jpg](attachment:MLinfograph5.jpg)
#
# Performance evaluation criteria as shown below was defined to ensure I pick the right machine learning model:
#
# ![mlperformancecriteria.png](attachment:mlperformancecriteria.png)
#
# Due to limited data availability, I decided to use the XGBoost and Random Forest algorithms and performance of both was very close.
#
# In terms of finding the most important feature, it was found out that the new feature created during feature engineering i.e. origin_bal_error (balance at the origin after transfer or cash-out) was the most important feature to be focused on as that is the starting point for the financial fraud.
#
# ![featureimportance.png](attachment:featureimportance.png)
#
# Here is the final summary of the model performance evaluation confirming why Random Forest is the recommended solution for this project:
#
# ![modelperformanceresults.png](attachment:modelperformanceresults.png)
#
# ![arrow.png](attachment:arrow.png)
# For the step by step details of the Machine Learning phase, please click at the <a href="https://github.com/jayguptacal/BankingAndInvestments/blob/main/FinancialFraudDetection/Financial_Frauds_Machine_Learning.ipynb" target="_blank">Machine Learning Notebook</a>. While opening this link, please open in a separate browser window by right-clicking and then opening it so that this summary notebook remains open. The data sometimes may not load properly, so please reload it until it shows properly.

# %% [markdown]
# ### Future Improvements<a id='6.2.7_Future_Improvements'></a>

# %% [markdown]
# - In future, I would like to use the <b>SMOTE (Synthetic Minority Oversampling Technique)</b> as data is imbalanced. I would like to use the <a href="https://github.com/scikit-learn-contrib/imbalanced-learn" target="_blank">Imbalanced-learn Library</a>.
#
# - In future, I would also like to focus on hyper-tuning the parameters for the machine learning models to get the better results using <b>GridSearchCV</b>.
#
# - For this project I did not use other machine learning models such as Logistic Regression and Decision Tree Classifier algorithms which I will use in future for a similar problem.
#
# - There is a very detailed report titled <a href="https://www.gsma.com/mobilefordevelopment/wp-content/uploads/2012/10/2012_MMU_Managing-the-risk-of-fraud-in-mobile-money.pdf" target="_blank">"Mobile Money for the Unbanked"</a> which states many techniques to mitigate these frauds. In future if there is more information available, I would like to focus on the mitigations too.

# %% [markdown]
# ### Credits<a id='6.2.8_Credits'></a>

# %% [markdown]
# Sincere thanks to following people who helped me in completing this project:
#
# - My amazing Springboard mentor Rajib Biswas who was always there for me.
#
# - E. A. Lopez-Rojas , A. Elmir, and S. Axelsson. "PaySim: A financial mobile money simulator for fraud detection". In: The 28th European Modeling and Simulation Symposium-EMSS, Larnaca, Cyprus. 2016; who created this phenomenal dataset for data scinece learners like me.

# %% [markdown]
# ### Jupyter Notebooks For Detailed Steps<a id='6.2.9_Jupyter_Notebooks'></a>

# %% [markdown]
# If you are interested in details of each phase, please refer the Jupyter Notebooks here one by one. While clicking on the below links for the detailed working of this project, please ensure that you open in a new window by right-clicking and then opening it so that this summary notebook remains open. The data sometimes may not load properly in the new window, so please reload it until it shows properly.
#
# * <a href="https://github.com/jayguptacal/BankingAndInvestments/blob/main/FinancialFraudDetection/Financial_Frauds_DataWrangling.ipynb" target="_blank"><b>Problem Identification and Data Wrangling Notebook</b></a>
#
# * <a href="https://github.com/jayguptacal/BankingAndInvestments/blob/main/FinancialFraudDetection/Financial_Frauds_Exploratory_Data_Analysis.ipynb" target="_blank"><b>Exploratory Data Analysis Notebook</b></a>
#
# * <a href="https://github.com/jayguptacal/BankingAndInvestments/blob/main/FinancialFraudDetection/Financial_Frauds_Preprocessing.ipynb" target="_blank"><b>Pre-Processing and Training Data Development Notebook</b></a>
#
# * <a href="https://github.com/jayguptacal/BankingAndInvestments/blob/main/FinancialFraudDetection/Financial_Frauds_Machine_Learning.ipynb" target="_blank"><b>Machine Learning Modeling Notebook</b></a>

# %% [markdown]
# ### Presentation Slides<a id='6.2.11_Presentation_Slides'></a>

# %% [markdown]
# ![financialfraudspresentationcover.png](attachment:financialfraudspresentationcover.png)
#
# If you want to refer the high-level presentation on this project, please click at the below link to access the presentation slides:
#
# * <a href="https://github.com/jayguptacal/BankingAndInvestments/blob/main/FinancialFraudDetection/financial_frauds_slides.pdf" target="_blank"><b>Financial Frauds Presentation Slides</b></a>
